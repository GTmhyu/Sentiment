# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score
import pickle
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
import string
import pandas as pd
import pymysql

# %%
def read_mysql_table(table, host='localhost', user='root', password='', database='review'):
    # Establish a connection to the MySQL database
    connection = pymysql.connect(
        host=host,
        user=user,
        password=password,
        database=database
    )
    
    # Create a cursor object to execute SQL queries
    cursor = connection.cursor()
    
    query = f"SELECT * FROM {table}"
    cursor.execute(query)
    result = cursor.fetchall()
    
    # Convert the result to a Pandas DataFrame
    df = pd.DataFrame(result)
    
    # Assign column names based on the cursor description
    df.columns = [column[0] for column in cursor.description]
    
    # Close the cursor and the database connection
    cursor.close()
    connection.close()
    
    return df

# %%
table_name = 'input_review'
df = read_mysql_table(table_name)
df.head()
# Out:
#    id_review   nama     tanggal review
# 0         29  sadam  1999-02-21   gyat

# %%
# text preprocessing
def preprocess_text(content):
    import nltk
    import re
    nltk.download('stopwords')
    nltk.download('punkt')

    # filtering

    text = re.sub(r'\W', ' ', str(content))
    text = re.sub(r'\s+[a-zA-Z]\s+', ' ', content)
    text = re.sub(r'\^[a-zA-Z]\s+', ' ', content)
    text = re.sub(r'\s+', ' ', content, flags=re.I)
    text = re.sub(r'^b\s+', '', content)
    text = text.lower() # case folding

    # Tokenisasi
    tokens = word_tokenize(text)

    # Menghapus stopwords
    stop_words = set(stopwords.words('indonesian'))
    tokens = [word for word in tokens if word.lower() not in stop_words]

    # Menggabungkan kembali tokens menjadi kalimat
    preprocessed_text = ' '.join(tokens)

    return preprocessed_text

# Melakukan preprocessing pada semua ulasan
df['preprocessed_text'] = df['review'].apply(preprocess_text)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\zmaul\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\zmaul\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
ulasan_bersih = df['preprocessed_text']

# %%
ulasan_bersih
# Out:
# 0    gyat
# Name: preprocessed_text, dtype: object

# %%
# Specify the file path of the pickle file
file_path = 'C:/Users/zmaul/OneDrive/Desktop/flask_input/mengajar-streamlit-main/TFIDF.pkl'

# Read the pickle file
with open(file_path, 'rb') as file:
    data_train = pickle.load(file)

# %%
data_train
# Out:
# ['in game masuk iklan . gamenya udh diselesain ikalan wajar , tp ditengah2 game iklan .',
#  'bikin game mewarnai bikin game penonton iklan ? .. 15 detik muncul iklan . lelang barang nonton iklan kadang iklanya bug nya yg ngulang nontonnya ...',
#  'ukurannya iklannya , sampah',
#  'elek game jelek game habis jual barang aneh penyimpanan ku cuman mb force close/keluar aplikasi',
#  'iklan mulu bbrp detik',
#  'iklannya kebangetan banget',
#  '1 % game , 99 % iklan game nyebelin yg gw mainin',
#  'main game nonton iklan',
#  'bahasanya ngerti udah ganti bahasa indo bala tetep aja bahasa',
#  'ditidak masuk game ... kecewa rating 1',
#  'iklan susah digerakkan',
#  'seru iklannya naudzubillah , klik iklan 15 detik , klik lg iklan . main gak nyaman . 10 menit install main lgsg uninstall lg . kecewa iklannya',
#  'iklan pake wifi klo pake pulsa/kuota iklan seru susah permainan nya tolong game kasih iklan sedikit² iklan ga cocok anak suka marahan klo aja iklannya deh terimakasih .',
#  'game nya sih bagus iklan main langsung iklan memainkan game nya iklan kaya terlalui iklan nya bintang ⭐ ( )',
#  'gamenya langsung ya , main belom gerakin kuas . kepengen main game keliatannya seru , gak dimainin . kecewa 😔 semoga diperbaiki yaaa 🙂🙏🏻',
#  'gw tau developer cape game . tp ga gini nyari uang . iklan bertebaran . next iklan . ulang iklan . bikin keselnya iklan ngambang pas lg mewarnai salah pencet langsung . pake solusi kalo emg dpet uang dr iklan kyk hint nya buka warna kek ga kek gini . kenyamanan pemain dipikir',
#  'udah berharap game , pas main udah coba kali hapus cache trs masuk lg tetep bgtu . udah gitu penyimpanannya lumayan gede ukuran game santai si , jujur kecewa bgt : ( (',
#  'halo perkenalkan nama naya akunx mama maaf banget kasih nilai 1 karna jelek 😡karna selesai . main 1× langsung masuk trus masuk knp yah ? ad yg bilang memory penuh yah 8 ram jd yah gitu tolong yah😊',
#  'iklan bertebaran bikin males main , sorry uninstall . iklan ganggu bgt , cari uang jg ga gini2 bgt kali . pencet dimana2 masuknya iklan . sumpah ganggu , sayang gamenya .',
#  'game nya gjelas banget , d buka langsung ... game rusak ! ! ! pdahal gw pengen nyoba ni game . mayan gabut kalo bosen maen game onlen . eh busuk 👎🏽👎🏽👎🏽👎🏽👎🏽💢😾👊🏼',
#  'game burik , kebanyakan iklan',
#  'udah download , orang main game , gak ! pusinggggggg nyebelin tolong dibenerin ya game nya iklan nya sekian terimakasih',
#  '',
#  'menginformasikan game mengalami bug . menggoreskan kuas kanvas , aplikasi nya langsung force close .',
#  'permainana sngat bagus , main knpa aplikasihnya logout ya , tolong diperbaiki , kesel nggak main krna kali main apk nya kluar sndiri',
#  'iklan nya game nya ramah bintang ⭐',
#  'menguras daya membukanya loadingnya banget pakai wifi 🐷 download dibuka ber jam²',
#  'bagus sih , kadang kesel , karna iklan nya , 5 menit udah iklan',
#  'game ga berguna , nyesel udah nginstal , iklannya',
#  'hapus game suruh hapus kek sih memori tingga 29gb ruang 2gb ga',
#  'udah dowlod nya aplikasinya udah suka pokoknya gak wortit dowlod udah dowlodnya nyesel de mendowlod aplikasi 🖕 udah nunggu main eh udah udah burik',
#  'game cocok suka melukis tau warna campur warna gitu dehh suka bangett game baguuss bangett makasi menciptakan game',
#  'dimainkan ! klik warna auto aplikasi , ga ! !',
#  'game rusak box pencampuran warna nya doang dipake lebihnya hitam ga keliatan pencampuran warnanya',
#  '10 menit main langsung uninstal , bayak iklan mengganggu bermain',
#  'pas selesai download main eh nga tau . dicoba kali aja kayk gitu hmm',
#  "game lemot banget pas main game nya seru banget tolong benerin udah ya wassalamu'alaikum",
#  'iklannya banget detikk sayang banget permainannya udah menarik',
#  'gabisa dimainin pas main langsung . . penasaran .',
#  'ni game anjir download kaga udh hapus 12 aplikasi aja kaga ni game nya sih ni game nya nge in hp orang aja',
#  'seru sih tapiii pas sy main iklan jd disaat jg sy uninstal😁 hahah sorry',
#  'game nya bagus bintang 5tapi kasih bintang 1 iklan benci iklan',
#  '& iklan',
#  'seru sii , tpi slalu force close mw main , mlah gk bsa , stack gitu , lngsung force close sbenar nya niat mw mainin gk sii ?',
#  'game gk jls , byk iklan stiap ronde sllu iklan smpe sy muak , udh gt mb nya gede bgt . auto uninstall si ..',
#  'game kebanyakan iklan ! ! aja main iklannya udah muncul teross',
#  'iklannya giilllaaaaa ..... tipa sekian detik iklan sekian detik iklan .. bener2 muaak😡😡😡😡',
#  'game rusak .. udh iklan nya bikin kesal pas download kekeluar mulu masuk',
#  'sy instal pas masuk game nya hitam kadang hp sy ngebalang tolong benarkan game nya sekian terima kasih🙏',
#  'aneh gabisa download disuruh hapus aplikasi , nyisa 4gb',
#  'iklan gak seruuu dikurangin iklannya',
#  'pas gw main game , wifi gw ga ngelag aja ga ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! gw kasi bintang 1 sory game tuh bagus yahhhh ! ! ! ! !',
#  'game nya . jelek ngambil warna merah ambil warna biru menerus hapus game nya deh , color match jelek . uuuuuuuuuuuu',
#  'game bagus mrlukis gak warna yg sesuai yg ngomong bacot yg suru susah cok',
#  'kebanyakan iklan . selesai 1 iklan iklan .',
#  'kebanyakan iklan . ngapa-ngapain iklan mulu',
#  'game nya bagus karna iklan nya',
#  'ya coba main layarnya kedap kedip hitam putih ?',
#  'game nya bagus sih tpi terkadang ngsln sih iklan mangkanya',
#  'game skrang sy jd suka bacot buah² ny berisik , iklan jg hadeh',
#  'gamenya gk dimainin . pas dimainin mulu , jd uninstall ajah deh',
#  'iklan nya , langsung uninstal',
#  'iklan , mengganggu ..',
#  'bagus tiba2 , ngulang gamenya',
#  'download 6 jam iklan download gak selesai selesai 👎',
#  'kebanyakan iklan gak bsa skip',
#  'game ga iklan mulu logout berkali kali . download buang buang kuota',
#  'maap suka karna susah buka permainannya maap ngga kasih reting karna emang susah buka',
#  'bilang iklan coba matiin data , gak iklan',
#  'mohon maaf loading nya banget tolong perbaiki ya',
#  'tiba2 ngak main , yg muncul video iklan smua',
#  'ga maenin game , pas lgs force close aja gitu ... device : poco x3',
#  'geme nya bagus iklan nya sampe 5 kali pertam main seru banget sumpah',
#  'kebanyakan iklan susah skip',
#  'jelek memainkan buah/sayur nya ngomong katain buah/sayur nya kesal kecewa',
#  'ga hapus plz',
#  'game yan si seru ikal nya udah mati data wifi ikal',
#  'bagus wifi bagus 🙏',
#  'download pas main langsung . gituuuuu trus',
#  'karna gem ya bagus 👍👍👍👍👍',
#  'masuk iklan nggak tombol',
#  'iklan , ga ngotak iklan nya',
#  'game bagusss cuman iklan main',
#  'ko gak download sihh tolong perbaiki ya gak tau knp sarat sarat nya',
#  'iklan oke gapapa . tp kebanyakan . cape seru : /',
#  'memori',
#  'bagus sih ngelag tolong perbaiki',
#  'iklan , brisik banget',
#  'gamenya bagus banget gak suka iklan nya',
#  'game nya bagus iklan mulu',
#  'sebenrenya ga kasih bintang sih game burik udh ngehapus game gak rugi gua',
#  'kalo ngasih iklan benerr kocak , w kasih tutor nih main yg bener',
#  'iklan mengganggu',
#  'game cacat , detik iklan',
#  'penuh iklan',
#  'iklannya',
#  'iklan',
#  'game 5 % iklan 95 % yg game cepat kaya',
#  'game nya banya iklan ya sapek kesel 13 menit udah ku hapus tolong kedepanya kurangi iklannya',
#  'jelek ... iklannya main gamenya',
#  'ga masuk gamenya tolong perbaiki ya',
#  'game bagus iklannya kayak k. o n t o l',
#  'gane burik gjls iklan trs bikin lag² hp',
#  'gak tau aja iklan nya',
#  'aneh banget game nya pencet warna langsung',
#  'gak gebukak',
#  'game dimainkan ,',
#  'gabisa dimainin ngelag mulu ga bsa hp spek kentang',
#  'game tolol bahasa indonya google translate suaranya',
#  'jleg ga main play tiba² back home',
#  'udh bayar no ads aja kena iklan , penipuan',
#  'susahh deh logout trs gamenya ngefrezzee tbtb gabisa diapa2 in 😭😭😭',
#  'iklan',
#  'banget iklannya',
#  'iklan',
#  'bikin bosen game nya iklan dowload guys game nya burik',
#  'iklan',
#  'mendingam nggak game-nya iklan aja .',
#  'pas loading game nya 👎🏻',
#  'bagus tema gamenya macet muluuuuuu keseel',
#  'iklan mulu g enjoy',
#  'gk asik anj download nya plus iklannya bejibun😑💔',
#  'si , gabisa mainin : (',
#  'gak mainkan udah downloadnya pulak',
#  "gak mainkan , ''",
#  'bagus keren menghasilkan uang 😎😎😎',
#  'udah exsaited banget hasil ny zoongg sia sia download dibuka aja',
#  'ga mainin , nge reset hp',
#  'kebanyakan iklann , geser dikitbiklan geser dikit iklann',
#  'game gak dimasuk kin gk sis 😡😡',
#  'seru mohon maaf iklannya dikurangi',
#  'main udah',
#  'iklan nya',
#  'game nya burik ga masuk permainan nya',
#  'jelek banget kebanyakan iklan woiii',
#  'iklan nya',
#  'ngelag memori yg segede',
#  'maaf kasih bintang 1 karna game 🙏🙏ini ga rekomend bgt ya',
#  'kurangin iklan nya',
#  'kebanyakan iklan bos',
#  'paansi njir perdetik iklan nya',
#  'sumpah marah bangettt ishh😤 , udah download ngga , download ehh udah 99 % ngga ish marah bangettt dehhh ngabisin kuota',
#  'permainan nya gak buakak padalan mb nya pokok nya donlot makasiiii .................. ! ; ! ! ! ! ; ; ! ! ; ; ; ; ; ; 🙄☺',
#  'game najis iklan',
#  'iklan',
#  'game nya gak masuk trus',
#  'apk nya ngeselin bgt udah bersihin memori hp ku gk bisa😤',
#  'aslinya seru cmn suka keluar2 sndiri .',
#  'game bagus , pencampuran warna',
#  'pas download gak bisa² padahl beli paketan',
#  'iklan ribet najis',
#  'game kebanyakan iklan',
#  'lemot iklan mulu',
#  'game nya aneh aja main eh hp ku eror',
#  'kebanyakan iklan',
#  'game nya iklann lemot bgt👎🏻👎🏻👎🏻',
#  'kebanyakan iklan',
#  'kebanyakan iklan',
#  'kebanyakan iklan',
#  'males kebanyakan iklan ! !',
#  'kebanyakan iklan',
#  'cari untung ! gerak dikit iklan ! ! ! permainan bagus mutunya ads ampe gak ad ruang gerak main !',
#  'gw pake poco x3 pro 8/256 main game aja forceclose wkwk',
#  'gak bagus download game nya gak seru 👎',
#  'normal game nya lemot🙂',
#  'susah banget cokkk',
#  'gk banget , main mulu -_-',
#  'gak install sihhhhhhhhhhhhhhhhhhhhhhh🤬',
#  'kebanyakan iklan',
#  'gak mainin tolong perbaiki',
#  'iklan nya : /',
#  'memori',
#  'iklan , ngelag',
#  'download nya banget sampe 2 kesel',
#  'pas mo mainin',
#  'gameny ba dimainin force close mulu',
#  'yah ? jringan lancar',
#  'barumain udh hasil kick game',
#  'gak instal sih ?',
#  'iklan lu ganggu banget',
#  'klo gini gamenya auto uninstall ga sih👿',
#  "kebnyakan iklan parah . biarin bntr '' iklan bikin kesel",
#  'lemot banget udah pake wifi lo',
#  'bacot , , klo kasi bintang 1 jelek knp disuruh ksi alasan lgi coba , , pokokkny nggakkkkkkk bagussss jellleeeeekkkkkk banget',
#  'bagus banget gamenya sumpah dah',
#  'game sampah , hp gw 8/128 prosesor snapnaga 700++ fc cuihhh',
#  'kebanyakan iklan',
#  'gimana maininnya , mah mbnya gede',
#  'kebanyakan iklan',
#  'ga mainin game nya',
#  '.. gak laahh seru',
#  'kebanyakan iklan',
#  'mainnyg bener donk kalo iklan',
#  'bagis bgt tp susah',
#  'sumph knp menginstal doang 175 mb lgi ah elah pusing',
#  'maen in g , iklan e bejibun',
#  'coba semoga sebagus foto nya',
#  'sumpah download aplikasi main masuk lazada',
#  'mainan bagus',
#  'jelek , ! ! !',
#  'seru iklan',
#  'bagus tp iklan wehh ! ! ! tolong kurangi iklan nya jd mengganggu ! !',
#  'lumayan bagus sih kalo main mulu game nya',
#  'sehari main .. lumayan ngasa otak',
#  'gamenya seru susah banget nentuin warna nya kasih bintang',
#  'hai , aja download apk . ngeluh game iklan . saran aja ya : ) , main mending matikan data wifi , trus udah selesai main nyalakan : ) . udah coba berkali kali game . ga game ya , game offline online , duanya gunain saran akuu . segitu aja , semoga bermanfaat ya man teman kasih rating 3 download',
#  'game nya sih bagus banget , asik iklan mulu bosen klo udah perbaiki udah gk iklannya kasih bintang 5 klo udah gk iklan nya ya٩😏۶',
#  'melanjutkan level isinya iklan , kadang pas main iklan . tolong diperbaiki',
#  'aseru susah',
#  'mencoba memainkannya iklannya keknya seru deh',
#  'lumayan , iklannya tolong kurangin iklannya😀😁',
#  "campur warna dih bagus v mash yg hrs d perbaiki , pergerakan kuasnya susahd . atur kaku jdi kadang suka k ''",
#  'main udah ngelag aja iklan gk tau pas iklan selesai warna layar hp ku hitam yaudah game pas ku pencet game nya ngulang donggg ! ! ! ! 🤔🤔😕tolong depelover nya perbaiki y 🤗🤗',
#  'game nya seru bagus , mohon iklan nya dikit karna main iklan main iklan mohon dikit iklan nya',
#  'download main eh tiba² wifi jg ngak lemot kasih bintang 3 ya tolong kesalahan diperbaiki ya .',
#  'bagus banget berkaryasi tolong iklan mulu kali udah selesai iklan bagus sih😊',
#  'suka gamenya karna bagus ngasah otak tp sayang iklannya download game refresing otak nonton iklan',
#  'suka ngelaikg seru',
#  'gamenya bagus , iklan . iklannya .',
#  'game nya bagus bngt seru tolong klo internet nya nyambung main iklan main iklan kesel main nya matiin internet ga ribet',
#  'game nya bagus , lumayan seru . iklannya pol , lumayan ngeganggu .',
#  'game bagus dimainin pas data nyala iklan nya nggak henti2 wehh kek nya kali gerak iklan mulu dahh parahhh sih .',
#  'game nya bagus si bagus ... iklan mulu tetep seru download gih seru tau ! ! ! ! ! 😀😀',
#  'bagus tpi iklan main bentar udah iklan lgi , capek nunggu iklan sih klok iklannya dihilangin aja ya',
#  'iklan ny bnyk ! ! ! ! ku kasih bintang 3 aj bynk kali iklan nya😤',
#  "game keren melati kreatifitas mohon perbaiki bug '' nya 👍",
#  'sih gamenya seru.tetapi karna banyaknya iklan , orang males main',
#  'nge bug .. .. iklan',
#  'maaf ya krna kasih bintang 3 gema nya emang seru gema nya iklan nya',
#  'bagus sih gerakin luas kiri susah uninstall tolong diperbaiki 😡😡',
#  'bagus tolong iklan nya kurangin gak seru main nya iklan',
#  'pas sentuh langsung ? mohon perbaiki bug nya',
#  'iklan nya kurangi peminat yg memainkan nya',
#  'tolong kurangi iklan , sayang banget kalo rating jelek karna kebanyakan iklan',
#  'bener bener ga worth it , game segitu gitu nya nyamain warna buah , mahal sih ampir 200 mb',
#  'iklan nya download nya jga iklan nya engbuang btw 3 🌟 aja ya',
#  "bagus iklan sesi : ' ( males maenya",
#  'iklan , sayang permainannya bagus',
#  'udah keren sih , forceclose iklannya',
#  'iklan nya banget . mah main iklan gratis game .',
#  'mb , iklannya gak bgt ya ☺',
#  'iklan bikin marah rekomendasikan main game ramadhan dad developer nya to long iklan nya banyak2',
#  'game nya seru mbosenin tolong dikasih kaya penghibur gitu . maaf kalo bintang doang . terimakasih😊😊😊',
#  'uninstall byk iklan . gk bs skip',
#  'game nya bagus iklan nya kecewa dikit sih 😥',
#  'game nya asik , cm iklannya bgt',
#  'bagus beriklan cma sesuai bahasa masing2',
#  'download gak tau seru kasih rating orang-orang iklan',
#  'iklan seru menarik',
#  'udh uninstall karna sy g main gara2 iklan .',
#  'gamenya bagus , iklannya bikin kesel',
#  'aplikasinya ya lumayan ........ donwload ko loading aja ya ........',
#  'bagus sih iklannya aja',
#  'permainan nya lumayan bagus',
#  'bagus pas donlod banget iklan lgi🗿🤘🏿',
#  'instal nya lamaaa tertunda terusss wifi udh masuk full game nya lumayan kasih 3 dehhh',
#  'bintang 3 dlu karna main iklan nya njir',
#  'lumayan sih loading nya banget adik sampe nangis tau wkwk , okelah gpp',
#  'iklan kayak main iklan 😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😔😔😔😔',
#  'seruh sih iklan',
#  'game nya bagus iklan',
#  'maaf gw cuman kasih bintang 3 plis tolong nih game kasi game online nya iklan terimakasi',
#  'nge lag banyakan iklan seru',
#  'iklan ,',
#  'geme nya bagus si tolong iklan nya kurangin👍😊😊',
#  'bagus si gemenya tpi iklannya',
#  'suka coba gk masuk karna ngeselin hapus masuk',
#  'seru tp lemot bgt grgr kbanyakan iklan gabisa offline',
#  'hpku mati tba2',
#  'iklan .',
#  'iklan',
#  'iklan nggak seru deg',
#  'hp ku eror karna iklan ga idupin data , , mohon maaf kasi binta 3 🙏🙏',
#  'iklan',
#  'bagus sih ulang ulang ya ? udah selesai eh keulang',
#  'banyakkkkkk iklan ..',
#  'game nya susah² gampang',
#  'seru sih ... tpi kebanyakan iklan , jdi males mainnya',
#  'seru',
#  'game seru banget ttt dah pola nya download ya',
#  'bagus suka kaya nya pke kouta ya susah klo gk kouta',
#  'game nya berisik risih buah and smacam nya ngonong terusssssss ,',
#  'gamenya seru loh gamenya download gamenya allah seru banget loh gamenya gamenya tanda seru banget gamenya pokoknya wajib banget deh kirim gamenya seru banget loh',
#  'iklannya',
#  'iklan ranting komentar kebanyakan',
#  'game nya seru banget seneng deh game kaya gini',
#  'gemes nya bagus macet suka 😡😡😡😡😡',
#  'yaaa , .. emng nyebelin iklannya',
#  'iklan',
#  'maaf ngasi bintang segini',
#  'mainan bagus',
#  'maaf ya ngehina susah nyari warnanya baguskok😊😊😊✔️✔️',
#  'tolong ya game lemot banget',
#  'gara gara iklan tik tok🗿',
#  'gajls bgt iklanya bikin nge lag',
#  'game ny membosankan sih ..',
#  'kasi bintang dlu , karna aja download nya .',
#  'geme bikin bosen',
#  'bosenin bgs jga ksih bintang 3 ya🌛',
#  'ya lumayan bagus sih guys',
#  'lumayan game nya',
#  'lumayan disaat gabut',
#  'bagus gem nya',
#  'suka lelet',
#  'gamenya bagus si ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! sayang iklan',
#  'belajar warna ( : 🐼🌼',
#  'bagus rada',
#  'lumayan bagus zzz',
#  'mainannya seru iklan',
#  'gatau blm download maaf 3',
#  'game nya bagus',
#  'suka empret',
#  'aga bagus 💤',
#  'magu susah',
#  'mainan nya bagus',
#  'bgus sih tpi membosankan',
#  'trelalu suka',
#  'ga dimainin 😩',
#  'game nya ngelag',
#  '',
#  'seru banget loh 😇😘😍',
#  'jelek ngebag',
#  'app ga',
#  'seru bangat permainannya',
#  'seru , mainnya🤭',
#  'susah bet njr 🗿',
#  'ya gitu deh',
#  'susah',
#  'bagus',
#  'aneh🙏',
#  'bagus',
#  'yess lumayan',
#  'lumyan',
#  'ads sucks',
#  'nih',
#  'suka ikl',
#  '𝕜𝕦𝕣𝕒𝕟𝕘 𝕓𝕒𝕘𝕦𝕤',
#  'baguss !',
#  'tolong kurangkan iklan',
#  'sukak',
#  'game seru bet',
#  'seru',
#  'keren',
#  'game lucu',
#  '',
#  'bagus',
#  'iya',
#  's u s a h banget nyamain warna nya🤬💩',
#  'to much ad session',
#  'dila',
#  'lumayan',
#  'bgs',
#  'seru',
#  'ngebag game ny',
#  'seruuu ! ! ! !',
#  'bagus',
#  "it 's actually a fun game but too many ads . i do n't mind one or two ads every 30minutes but one ad every few second is just too much ..",
#  'suka',
#  'lumayan oke',
#  'nice',
#  'good',
#  "ok , what do you think of this game , anyway , just plugged it in and then it came out on its own but it 's okay i gave 3 stars",
#  'iklan',
#  'bagussss',
#  'bikin tiktok ilang',
#  'ngelag',
#  'seruuuuuuu ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! !',
#  'good',
#  "so sorry but u make my phone ruin . when i play this game my phono run so slow and frequently buffering if i connect to internet . 😭 and while i open other application after play this game my phone become weird . actually i also play game that 's had more data to download but my phone just fine . no more buffer etc . : )",
#  "this is a really good game , but the ads are too many so please delevoper reduce the ads i 'm really annoyed : (",
#  'hm this game kinda cool for mini artis kids but kinda lag and yea byeeeee',
#  'bagua',
#  'b aja',
#  'lumayan sehhhhhhh',
#  'lag bngt',
#  'iklan mebeludag',
#  'gak bagus',
#  'lumayan bagus',
#  'oke',
#  'gampang',
#  'bagusss',
#  'gtw',
#  'asu',
#  '😳😳😳',
#  '👍',
#  'mending',
#  'ga bgt',
#  '',
#  '',
#  'ajaa',
#  'bosen',
#  'fitur',
#  'yauda iya',
#  'gg',
#  '',
#  'lumayan bagus',
#  'yabegitu',
#  'lumayan membantu',
#  'keren aplikasinya',
#  'bagus',
#  'game nya seru dn gk iklan tpi susah nyampurin warna nya seru offline',
#  'game menarik bagus . main game iklannya matikan data wifi rumah . permainan kuasnya susah gerakkan . dah bagus perbaiki ya devoloper kasih bintang 5 bersemangat memperbaiki game ok sekian terima kasih w assalamualaikum 👋👋👋',
#  'seru banget susah bikin warnanya kayar seru banget gitu😄😄',
#  'game seru gampang sesuai warna',
#  'wow seru stres asik main main 2019 sapai seru kalo salah ulang aku🙏🏻🙏🏻🙏🏻🥰🥰🥰',
#  'bagus bgt anjirrr kyk g lag sma',
#  'permainan bagus stres',
#  'tolong hilangin iklan nya gak enak kalo iklan',
#  'wow keren banget gem',
#  'kasi bintang harapan force close nya diperbaiki device renot 10 pro pengen memainkan game yg sesuai bidang bidang seni rupa . apl lancar berjalan . tolong developer tolong diperbaiki apl nya',
#  'heiii game offline kalo iklannya ya matiin aja wifi/datanya',
#  'permainan bagus sya suka memainkan nya',
#  'permainannya seru gak bikin gabut',
#  'bagus suka kalo ngehilangin iklan mati in data/wifi gampang warna nya kalo gk sampe 100 % langsung terobos pokoknya seru deh kalo gabut doang sih mainnya : )',
#  'game seru banget , kalo gamau iklan . matiin data aja wifi , game gaaada kendala apapun , seru warna nya terobos loh , gausah banget warna nya , seru deh bintang 5 , game nya lag hp nya yaaa , kalo ga lag',
#  'game bagus iklannya ya tolong i iklan.gamenya ok susah disamakanya.1ke2 nya gampang susah banget ya.makasi karna sjaa keluhan saya.tetapi kasi bintang 5',
#  'hai perkenalkan nama ayra , game nya seru banget , oh iya main game nya iklan gak matiin data wifi , sebener nya game nya gak iklan nya . ok sekian penilai an salam kota pagar alam🌿🍃',
#  'permainan nya bagus banget suka banget iklan nya gak gak lihat iklan matikan aja paket data wifi gak iklan .... buruan download gak nyesel deh',
#  'gemenya bagus sih , lumayan iklan nunggu , kadang iklannya ( bentar ) , suka gemenya wajib download ya , kasih bintang hehe gapapa lihat kebawah ikhlas ☺️☺️',
#  "game seru developer perbaiki game karna game . semoga perbaiki benar-benar perbaiki , kasih bintang 5 harapan perbaiki game . yaudah semoga developer perbaiki game force close perbaiki . main sepuasnya lupa sholat , belajar , ngaji biar pinter okay ? assalamu'alaikum warohmatulohi wabarakatuh .",
#  'game nya bagus , cuman ngasih tau yg bilang game nya ngelag iklan , gamenya ngelag karna penyimpanan hp hmpr habis , matiin data/wifi biar gk iklan , trimakasih',
#  'game enak',
#  'bagus meltih kreativitas adikku bagus yey',
#  'game nya bagus kuas nya susah ngambil warna.kuas nya ngambil warna hijau keambil warna merah warnanya . iklan nya tolong kurangin iklanya iklannya menggangu menyamakan warna nya game bagus bicara mengasih clue warna nya clue nya kayak gak gitu warna nya cerah pas cerahin gak cocok',
#  'game seru banget loh keren game',
#  'geam nya seru banget kasih bintang karna suka geam cobain deh seru banget ni main geam nya ide komentar aplikasi play store permainan seru ayo download play store aja yauda dada',
#  'game seru menyenangkan☺️',
#  'gamenya 🅑🅐🅖🅤🅢 iklan developer , tolong kurangin iklanya ya 😊👍 dikurangin tetep kasih bintang 5 dikurangin sebulan kurangin bintangnya makasih .',
#  'permainan bagus',
#  'game nya bagus daat warna warna tulisan nya pokok nya bagus de',
#  'gamenya bagus banget menyenangkan dipakai belajar nyatuin warna pokoknya bagus banget deh ...',
#  'geme nya bagus iklan',
#  'menyenangkan , bosan',
#  'seru banget pas udh kuasain campurin warnanya bias dapet nilai 100. 2-3 main udah namatin . sayang bgt levelnya',
#  'permainannya bagus , permainan iklan menghidupkan internet wifi . intinya tujuan permainan mencampurkan warna warna warna buahnya jual simpan .',
#  'seru bahasa indo nya susahh pencett',
#  'game ny bagus org yg bilang klo game ny lag tu hp yg kebanyakan memori jdi mohon maaf🙏 ya dn iklan nya tinggal matiin data wifi ny deh selamat coba samoga bermanfaat ya',
#  'game ngebug kah ? beli perabotan muncul asap gitu tandanya perabot diruangan gaada yg muncul lantai .',
#  'permainnan bagus gak kekurangan suka',
#  'bagus game nya iklan nya aja',
#  'bagus banget belajar warna bikin warna parti tulisan warna apanya klo gk donwload nyesel si',
#  'game bagus menyenangkan orang bilang iklan tinggal matiin wifi/data mudah',
#  'game seru banget , tp sy bingung knp ulasan bilangnya gk main , sy bisa² aja ? anw sy suka game',
#  'suka game nya g pokok nya yg taku nge download game karna iklan merapat game color match cocok yg g suka iklan kayak',
#  'permainan nya bagus banget lumayan iklan nya gak papa bagus game nya rate bintang 5',
#  ", yg jln keluarnya , iklan iseng '' download tau '' menenangkan pikiran 🤧🥰🥰👍👍❤️❤️ terimakasih 🙏☺️",
#  'bagus ss suka',
#  'game inj seru bangettt wajib download game seruu banget nyesel kalo ga download btw kalo iklan datanya matiin ya semoga bermanfaat☺😊😁',
#  'game nya bagus seru ade sepupu suka , suka campur² warna kalo kertas nya habis alu kasih pinjem game',
#  'game seru suka matiin wifi data ga iklan kasih bintang 5 seru banget',
#  'game nya bagus banget data wifi nya nyalain tetep gaada iklan nya',
#  'permainan nya bagus banget suka ngk iklan nya nyalain aja mode pesawatnya 😄😁',
#  'game nya bagus suka iklan mohon perbaiki tetep kasih bintang 5',
#  'seru banget tolong tambahkan milih level level nya banyakin',
#  'game sngat seru nyaman , kesel game iklan oke aja sih',
#  'bagus mainannya iklanya nunggu kadang kadang sebentar',
#  'suka permainan , karna warna dicampur menghasilkan warna .',
#  'game bagus , mengajari menggabungkan warna benar😁',
#  'bagus sih ✋ muncul gua nonton anime baca manga , semacamnya bagus sesuai ekspektasi gua ya tersendiri 😉',
#  'game bagus iklannya tolong dikurangi ngeleg wifi ku coba diidupkan saja😰😰😡😡😡😡😡😡😡😡😡😡😡😡😠😠😠😠😠😠😠😠🤬🤬🤬🤬🤬🤬🤬🤬🤬🤬😤😤😤😤😤😤😤😤😤😤😤🥵🥵🥵🥵🥵🥵🥵🥵🥵🥵🥵🥵🥵',
#  'game nya seruu , cuman msalah nya cerewet huhu , iklan nya , rada kecewa : (',
#  'game nya seru banget iklan , klompok pingin gda iklan tinggal data/wi-fi matiin',
#  'gemnya bagus tolong kurangin iklannya iya nya gem nya bagus',
#  'game nya seru banget iklan 🙏🙏🙏 ... oh iya deh kasih bintang 5 ya',
#  'seru banget iklan tinggal mati in data wifi klo englet yh salah hp aj kali y ok sekian terimakasih',
#  'gem nya bagus kalok warnanya salah ulang iklan nya gak',
#  'permainannya bagus mempelajari mencampur warna ☺',
#  'permaenan bagus dikit dikit iklan mulu gpp suka permaenan 👍👍 bagus bagus 👍👍',
#  'game nya seru t-tapi padaku main buah pengen lainya tolong diperbai ya',
#  'gem sanagat seru suka mewarnai gem cocok suka gem i like it ❤️',
#  'bagus permainannya data wifi nya dimatikin gak iklan',
#  'game nya bagus banget jualan pokoknya gemes banget game ini😘🥴',
#  'tau si geme nya bagus tiba2 memoriku penuh instal permainan',
#  'permainan nya bagus melatih otak warna anak ²',
#  'bagus banget nenangin stress sayangnya membosankan warnanya aja',
#  'kayaknya sih dowloand bagus pas buka iklan unistal🙃',
#  'gsmenya bagus pas setoortyi warnanya . coklat moon perbikin',
#  'gem nya bagus sayang nya iklannya',
#  'bagus permainannya seru ade suka banget debes banget',
#  'gamenya pintar melukis mencocokan warna',
#  'game nya bagus tpi iklan nya',
#  'game nya bagus bgt kasih bintang 🌟🌟🌟🌟🌟 bagus banget adk ak yg umr ny 3/5 cocok bgt adk ak seneng bgt cakep bgt deh hrs download deh download jga bye main dlu sm adk ak bye 🤗😍🥳🤩😄😘🤭🇮🇩♥️🇰🇷 bye bye mauch',
#  'mb-nya banget 237 * download banget ganti mb-nya play store',
#  "halo , bilang kalo ngelag hp , iklan , tinggal matiin data wifi , wassalamu'alaikum🙏🙏",
#  'sumpah game seru banget mami nyuruh hp main game gak tuntas tuntas pokoknya free bagusnya indonesia raya 1 bumi anak-anak main mencampurkan warna mendownload game menyampurkan warna mendownload game jago menyampurkan warna terima kasih mainan suka banget mainannya pokoknya senang banget download kak tuntas tuntas mainan cari bagus bagus',
#  'gem ya bagus iklan 1pun klian donglot ya ! ! ! ! ! ! ! ! ! ♥️❤️',
#  'bagus cumak iklan bagus',
#  'seru , cocok karna pintar membedakan warna .',
#  'apk mantaf berkat apk skarang sya sudh usaha oplos cat .',
#  'game nya bagus iklan',
#  'game nya bagus banget kasik bintang 5 karna pas kali main game ketagihan langsung download ya teman teman',
#  'game bagus banget susah nyocokin warna nya , game bagus banget download y😁😁😁😁',
#  'bagus suka game ini😋😋👍🏻👍🏻👍🏻',
#  'main bagus 😇',
#  'game ya bagus banget',
#  'game nya seru banget',
#  'game nya menarik suka mewarnai menggambar 😇💕',
#  'gamenya gak ngebosenin bagus banget makasih color match',
#  'bagus banget seng terimakasih',
#  'sukaaaaaaaaa akuuuu sukaaaaaaa game ny baguss bangettttt naikin mood bikin happy iklan ny diilangin aj ngeganggu',
#  'banget bagus iklan gak',
#  'bagus lancar menggabung warna makasih yen bye bye doang kasih bintang 5',
#  'gamenya bagus hilangkan iklannya ya',
#  'keren banget nih blum cat dirumah makai game ! ! ! ⭐',
#  'bagus banget gemnya .. iklan teruss 😌',
#  'suka game nya seru melatih pewarnaan',
#  'halo nama dinda umur ku 11 kali nge download game udah game nya bagus teryata emang bagus game nya seru suka ngecampurin warna warna . jamin g abakapan nyesel deh nge download game',
#  'game bagus bgttt kalo ngelek/bug / iklan matikan wifi/data aja udah😛😛😛😛',
#  'bagus 100 % akurat',
#  'game bagus banget gak kekurangan nya download',
#  'wahh bagus banget nih game ank - ank tau warna nih wajib donload ya gusy😇',
#  'suka gamenya belajar warna😊😊',
#  'gem nya bagus tolong bicara nya ya makasih .',
#  'bagus kebanyakan iklan',
#  'bagus lucu kalo ngomong🤣😂',
#  'bagus belajar warna anak²',
#  'cocok healing sih ... gabut main aja ... worth it',
#  'bagus sih tp iklan',
#  'gamenya asyik bangeeeettt ...',
#  'seruu cuman iklan mengganggu',
#  'game banget belajar campur campur warna',
#  'game yg menarik menyenangkan luang',
#  'bagus banget udah gitu offline lsgi',
#  'geme nya bagus banget bahasa indonesia langi',
#  'game nya bagus enak maini pilihan',
#  'game nya bagus banget nambah pengetahuan warna',
#  'bagus banget mempelajari campuran warna',
#  'permainan bagus banget mencampur campur warna',
#  'gamnya bagus klo gk iklat tinggal matikan wivi internet gk ad iklan trimakasih 😊',
#  'seruu skali , tpi iklan',
#  'game bagus iklan',
#  'download todak mainkan tolong mendownload mendonwload game tolong kali mainkan ! ! ! ! ! ! ! ! !',
#  'game bagus cita cita nya melukis',
#  'game iklan nya suka',
#  'permainannya enak dimainin biar anak mencampur campur warna',
#  'weh game nya bagus banget 😎 klo mainnya ga 😎😎hanya hp vivo yg main',
#  'bgua banget sih game nya belajar campur² warna',
#  'bagus . membantu anak nemcampur warna !',
#  'suka aplikasi menemani gabut ayo gak pikir pikir langsung mainin',
#  'youtube buah nya marah in ngak marah in perfec btw game nya seruh loh gusy',
#  'seru bermain game senang warna buah dunia',
#  'emang beneran seru banget . cocok banget belajar mencampur warna biru hijau kuning',
#  'bagus si cuman iklan shoopie mengganggu ya hehhehehe',
#  'game nya bagus 😍👍😍👍😍👍😍👍 bikin emosi',
#  'bagus banget . campur-campur warna beli-beli',
#  'bagus baget ki iklan nya 5 kali sih',
#  'bagus banget mainnya makasih banget yyyyyyy',
#  'suka gabut main game bintang 5 !',
#  'game bagus donwload nya gakpaksa ko 😊',
#  'permainan bagus belajar',
#  'bagus menetes konsentrasi',
#  'seru bgt gem nya bagus anak gak boros kuota wifi',
#  'bagus cocok main tau warna seru langsung donglod',
#  'bagus ga iklan',
#  'sih keren banget susah ngepasin warna merah muda campur kuning campur biru hijau ketua mudaan',
#  'keren banget game nya kalo gas download gak pake kuota',
#  'game nya bagus mencampur warna sempurna',
#  'bagius banget ga pake . iklan deh cocok kalo gabut main',
#  'game ya bagus campuran warna',
#  'bagus melatih anak',
#  'bagus banget permainannya fix sih donlod',
#  'game nya bagus dongk mangkanya make hp tuh ram nya gede biar bebas main ap aje',
#  'keren bngtt kga iklan',
#  'bagus banget unit anak anak balita tau warna',
#  'gamenya bagus ngapain liat scrol kebawah udh bilangin bagus yah bagus',
#  'ngakak liat iklan nya liat kak fanny tjandra mainin game tertarik aku😅',
#  'game seru banget bangetbanget banget banget bangetbanget banget nya pol',
#  'game nya bagus bingung ngomong download 👍👍👍👍👍👍',
#  'seru banget + belajar mencampur warna suka banget',
#  'gems bagus yg orang gede mengerti menyampur warna terimakasih',
#  'nunggu loading nya lamaaaaa hp lu tuh kennnnnntaaaaaang',
#  'game nya seru sih iklanya terus-teeusan hah 😆🤣',
#  'seruuu banget . coba langsung dapet seratus 😭😭😭😭',
#  "kesini karna iklan terong ngoceh warnanya ga trs bilang 'the tomato was right ' 🤣 .. kirain buah-buahan nya beneran komen tyt aslinya ga",
#  'gamenya seru banget deh pokoknya suka banget gamenya',
#  'seru banget permainan nya warna apa²saja campur warna nya',
#  'game nya bagus buta warna wkwkwkwkwk',
#  'game bagus bangeeeet paraaaaaah download game bagus banget sumpah bagus',
#  'woww game mah seru bgt , mengenal byk warna , bermanfaat game 💯👍',
#  'bbl bbl bagus banget loh tp² buanyak pol iklannya tpii gpp yg orang² suka',
#  'gamenya seru suka banget adik ku suka banget 😊😊😊😊',
#  'permainan nya bagu sayang mb nya 169',
#  'seru , main mencampur - campur warna . menyenangkan !',
#  'game nya seru menarik',
#  'game nya bagus gak kekurangan 👍👍👍',
#  'gemnya asik',
#  'gatau gamenya download wkwkwkwkwkwkwkwkwkwkwkkwkwkwwkkwkwwkwkkwwkkwkwkwkwkwwwkkwkwwkwkwkw ( wkwkwkwkwkwkwkwkwkwkwkwkwkwkwkkwkwkwkwkkwkwkwkwkkwkwkwkwkwkwkkwkwkwkwkwkwkkwkwkwkwkwkwkwkkwkwkwkwkwkwkkwwkkwkwkwkwkkwkwkwkwkwkkwwkkwkwkwkkwkwkwkwkwkkwkwkwkwkwkwkwkkwkwkwkwkwkwkkwkwkwkwk',
#  'bagus , btw gue nulis bagus karna mager',
#  'bagus banget sumpah bagus banget gw suka banget',
#  'lumayan ngisi senggang ngasih skil art',
#  'mainan ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! bohong jelek kasih bintang',
#  'puas permainan',
#  'gamenya bagus sih bkin nyesel susah banget',
#  'gem ya seru enak main',
#  'geme nya bagus bangetttt suka gm , kasi bintang heheh',
#  'susah game nya bagus kasih bintang yaa',
#  'asalamualaikum nama hepti game seru bet suka lemot hp ku',
#  'seru banget deh main cepetan donlut game mangkanya game kasih bintang',
#  'memusing bagus',
#  'game nya asik , seru , lag💯']

# %%
# pembuatan vector kata
vectorizer = TfidfVectorizer()
train_vector = vectorizer.fit_transform(data_train)
reviews2 = ["".join(r) for r in ulasan_bersih]

# %%
reviews2
# Out:
# ['gyat']

# %%
load_model = pickle.load(open('C:/Users/zmaul/OneDrive/Desktop/flask_input/mengajar-streamlit-main/svm_model.pkl','rb'))

result = []

for test in reviews2:
    test_data = [str(test)]
    test_vector = vectorizer.transform(test_data).toarray()  # Convert to dense matrix
    pred = load_model.predict(test_vector)
    result.append(pred[0])

# %%
result
# Out:
# [3]

# %%
from sklearn.utils.multiclass import unique_labels
unique_labels(result)
# Out:
# array([3], dtype=int64)

# %%
df['label'] = result

# %%
def delete_all_data_from_table(table, host='localhost', user='root', password='', database='review'):
    # Establish a connection to the MySQL database
    connection = pymysql.connect(
        host=host,
        user=user,
        password=password,
        database=database
    )
    
    # Create a cursor object to execute SQL queries
    cursor = connection.cursor()
    
    # Delete all data from the specified table
    query = f"DELETE FROM {table}"
    cursor.execute(query)
    
    # Commit the changes
    connection.commit()
    
    # Close the cursor and the database connection
    cursor.close()
    connection.close()

# %%
delete_all_data_from_table('input_review')

# %%
def insert_df_into_hasil_model(df, host='localhost', user='root', password='', database='review'):
    # Establish a connection to the MySQL database
    connection = pymysql.connect(
        host=host,
        user=user,
        password=password,
        database=database
    )

    # Create a cursor object to execute SQL queries
    cursor = connection.cursor()

    # Insert each row from the DataFrame into the 'hasil_model' table
    for index, row in df.iterrows():
        query = "INSERT INTO hasil_model (id_review, nama, tanggal, review, label) VALUES (%s, %s, %s, %s, %s)"
        cursor.execute(query, (row['id_review'], row['nama'], row['tanggal'], row['review'], row['label']))

    # Commit the changes
    connection.commit()

    # Close the cursor and the database connection
    cursor.close()
    connection.close()

# %%
insert_df_into_hasil_model(df)

# %%
table_name = 'hasil_model'
hasil_df = read_mysql_table(table_name)
hasil_df.to_csv('Data/hasil_model.csv')
